# %%
#my test

# %%
sqfeet = [10, 20, 30, 40]
house_prices= [100, 200, 300, 400]

# %%
def costfunction(x, y, w, b):
    m = len(x)
    sum = 0
    for i in range(m):
        y_ = w * x[i] + b
        f_wb = (y_ - y[i]) ** 2
        sum = sum + f_wb
        print(y_)
    totalsum = (1 / (2 * m)) * sum
    return totalsum

# %%
def gradient(x, y, w, b):
    m = len(x)
    dj_dw = 0
    dj_db = 0

    for i in range(m):
        f_wb = w * x[i] + b
        dw = (
# Out:
# 80
# 160
# 240
# 320
# 1500.0

# %%
# Out:
# ...
# STEP 1: PREPARE DATA
# ...
# Training examples: 4
# x (square feet): [100 200 300 400]
# y (house prices): [1 2 3 4]
#
# ...
# STEP 2: COST FUNCTION DEFINED
# ...
# This measures how wrong our predictions are
#
# ...
# STEP 3: GRADIENT COMPUTATION DEFINED
# ...
# This tells us which direction to move w and b
#
# ...
# STEP 4: GRADIENT DESCENT ALGORITHM DEFINED
# ...
# This iteratively updates w and b to minimize cost
#
# ...
# STEP 5: RUNNING GRADIENT DESCENT
# ...
#
# Starting Gradient Descent...
# Initial parameters: w = 10.0, b = 0.0
# Learning rate: 1e-05
# Iterations: 1000
#
# Iteration | Cost          | w         | b         | Gradient_w | Gradient_b
# --------------------------------------------------------------------------------
#         0 |  3742503.7500 |  2.507500 | -0.024975 |  749250.00 |    2497.50
#       100 |        0.0001 |  0.010111 | -0.033294 |       0.00 |      -0.01
#       200 |        0.0001 |  0.010111 | -0.033289 |       0.00 |      -0.01
# ...
